# %%
import wradlib as wrl
import numpy as np
import os
# Set the WRADLIB_DATA environment variable
os.environ['WRADLIB_DATA'] = 'wradlib_data'

# %%
fpath = "scan-sidpol-120km-14_20001_20240814000001_00.h5"
f = wrl.util.get_wradlib_data_file(fpath)
data, metadata = wrl.io.read_gamic_hdf5(f)

# %%
print(metadata.keys())
print(metadata["VOL"])
print(metadata["SCAN0"].keys())
# Out:
# dict_keys(['SCAN0', 'SCAN1', 'SCAN10', 'SCAN11', 'SCAN12', 'SCAN13', 'SCAN2', 'SCAN3', 'SCAN4', 'SCAN5', 'SCAN6', 'SCAN7', 'SCAN8', 'SCAN9', 'VOL'])
# {'Latitude': np.float64(49.094167), 'Longitude': np.float64(8.436667), 'Height': np.float64(148.0)}
# dict_keys(['PRF', 'adc_hh_temperature', 'adc_hh_temperature__unit', 'adc_hl_temperature', 'adc_hl_temperature__unit', 'adc_vh_temperature', 'adc_vh_temperature__unit', 'adc_vl_temperature', 'adc_vl_temperature__unit', 'angle_step', 'angle_sync', 'ant_gain_h', 'ant_gain_h__unit', 'ant_gain_ldrh', 'ant_gain_ldrh__unit', 'ant_gain_ldrv', 'ant_gain_ldrv__unit', 'ant_gain_v', 'ant_gain_v__unit', 'azi_start', 'azi_stop', 'bin_count', 'clutter_filter_number', 'cpu_temp_0', 'cpu_temp_0__unit', 'cpu_temp_1', 'cpu_temp_1__unit', 'cpu_temp_2', 'cpu_temp_2__unit', 'cpu_temp_3', 'cpu_temp_3__unit', 'dbm0_h', 'dbm0_h__unit', 'dbm0_v', 'dbm0_v__unit', 'dbz0_h', 'dbz0_h__unit', 'dbz0_v', 'dbz0_v__unit', 'elevation', 'gas_attenuation', 'gas_attenuation__unit', 'ldr_offset', 'ldr_offset__unit', 'malfunc', 'mb_temp_0', 'mb_temp_0__unit', 'mb_temp_1', 'mb_temp_1__unit', 'mb_temp_2', 'mb_temp_2__unit', 'mb_temp_3', 'mb_temp_3__unit', 'noise_power_h', 'noise_power_h__unit', 'noise_power_v', 'noise_power_v__unit', 'noise_threshold', 'noise_threshold__unit', 'nyquist_velocity', 'nyquist_velocity__unit', 'phidp_offset', 'phidp_offset__unit', 'pulse_width_number', 'pulse_width_us', 'pulse_width_us_0', 'pulse_width_us_0__unit', 'pulse_width_us_1', 'pulse_width_us_1__unit', 'pulse_width_us_2', 'pulse_width_us_2__unit', 'pulse_width_us_3', 'pulse_width_us_3__unit', 'radar_wave_length', 'range', 'range_samples', 'range_start', 'range_step', 'raster', 'ray_count', 'rx_loss_h', 'rx_loss_h__unit', 'rx_loss_ldrh', 'rx_loss_ldrh__unit', 'rx_loss_ldrv', 'rx_loss_ldrv__unit', 'rx_loss_v', 'rx_loss_v__unit', 'scan_speed', 'swap_phidp', 'time_samples', 'tsg_loss_h', 'tsg_loss_h__unit', 'tsg_loss_ldrh', 'tsg_loss_ldrh__unit', 'tsg_loss_ldrv', 'tsg_loss_ldrv__unit', 'tsg_loss_v', 'tsg_loss_v__unit', 'tx_loss_h', 'tx_loss_h__unit', 'tx_loss_ldrh', 'tx_loss_ldrh__unit', 'tx_loss_ldrv', 'tx_loss_ldrv__unit', 'tx_loss_v', 'tx_loss_v__unit', 'txd_peak_power', 'txd_peak_power__unit', 'unambiguous_velocity', 'unambiguous_velocity__unit', 'unfolding', 'unfolding_str', 'zdr1_offset', 'zdr1_offset__unit', 'zdr_offset', 'zdr_offset__unit', 'bin_range', 'zero_index', 'az', 'el', 'r', 'Time', 'max_range'])

# %%
metadata
# Out:
# {'SCAN0': {'PRF': np.uint32(1180),
#   'adc_hh_temperature': np.float64(58.0),
#   'adc_hh_temperature__unit': 'degC',
#   'adc_hl_temperature': np.float64(56.0),
#   'adc_hl_temperature__unit': 'degC',
#   'adc_vh_temperature': np.float64(56.0),
#   'adc_vh_temperature__unit': 'degC',
#   'adc_vl_temperature': np.float64(58.0),
#   'adc_vl_temperature__unit': 'degC',
#   'angle_step': np.float64(1.0),
#   'angle_sync': np.uint8(1),
#   'ant_gain_h': np.float64(45.7),
#   'ant_gain_h__unit': 'dB',
#   'ant_gain_ldrh': np.float64(45.7),
#   'ant_gain_ldrh__unit': 'dB',
#   'ant_gain_ldrv': np.float64(43.0),
#   'ant_gain_ldrv__unit': 'dB',
#   'ant_gain_v': np.float64(45.8),
#   'ant_gain_v__unit': 'dB',
#   'azi_start': np.float64(0.0),
#   'azi_stop': np.float64(0.0),
#   'bin_count': np.uint32(240),
#   'clutter_filter_number': np.uint32(4),
#   'cpu_temp_0': np.float64(34.0),
#   'cpu_temp_0__unit': 'degC',
#   'cpu_temp_1': np.float64(0.0),
#   'cpu_temp_1__unit': 'degC',
#   'cpu_temp_2': np.float64(0.0),
#   'cpu_temp_2__unit': 'degC',
#   'cpu_temp_3': np.float64(0.0),
#   'cpu_temp_3__unit': 'degC',
#   'dbm0_h': np.float64(-106.231),
#   'dbm0_h__unit': 'dB',
#   'dbm0_v': np.float64(-105.436),
#   'dbm0_v__unit': 'dB',
#   'dbz0_h': np.float64(-35.1336),
#   'dbz0_h__unit': 'dBZ',
#   'dbz0_v': np.float64(-34.679),
#   'dbz0_v__unit': 'dBZ',
#   'elevation': np.float64(0.4010009765625),
#   'gas_attenuation': np.float64(0.016),
#   'gas_attenuation__unit': 'dB/km',
#   'ldr_offset': np.float64(0.0),
#   'ldr_offset__unit': 'dB',
#   'malfunc': np.uint8(0),
#   'mb_temp_0': np.float64(31.0),
#   'mb_temp_0__unit': 'degC',
#   'mb_temp_1': np.float64(0.0),
#   'mb_temp_1__unit': 'degC',
#   'mb_temp_2': np.float64(0.0),
#   'mb_temp_2__unit': 'degC',
#   'mb_temp_3': np.float64(0.0),
#   'mb_temp_3__unit': 'degC',
#   'noise_power_h': np.float64(2.10011),
#   'noise_power_h__unit': 'dB',
#   'noise_power_v': np.float64(2.96022),
#   'noise_power_v__unit': 'dB',
#   'noise_threshold': np.float64(0.0),
#   'noise_threshold__unit': 'dB',
#   'nyquist_velocity': np.float64(15.7471),
#   'nyquist_velocity__unit': 'm/s',
#   'phidp_offset': np.float64(0.0),
#   'phidp_offset__unit': 'deg',
#   'pulse_width_number': '4',
#   'pulse_width_us': np.float64(0.8050000071525574),
#   'pulse_width_us_0': np.float64(0.4),
#   'pulse_width_us_0__unit': 'us',
#   'pulse_width_us_1': np.float64(0.805),
#   'pulse_width_us_1__unit': 'us',
#   'pulse_width_us_2': np.float64(1.0),
#   'pulse_width_us_2__unit': 'us',
#   'pulse_width_us_3': np.float64(2.0),
#   'pulse_width_us_3__unit': 'us',
#   'radar_wave_length': np.float64(0.053380001336336136),
#   'range': np.float64(120000.0),
#   'range_samples': np.uint32(4),
#   'range_start': np.float64(0.0),
#   'range_step': np.float64(125.0),
#   'raster': 'off',
#   'ray_count': np.uint32(361),
#   'rx_loss_h': np.float64(3.59),
#   'rx_loss_h__unit': 'dB',
#   'rx_loss_ldrh': np.float64(3.59),
#   'rx_loss_ldrh__unit': 'dB',
#   'rx_loss_ldrv': np.float64(4.1),
#   'rx_loss_ldrv__unit': 'dB',
#   'rx_loss_v': np.float64(4.11),
#   'rx_loss_v__unit': 'dB',
#   'scan_speed': np.float64(28.0),
#   'swap_phidp': 'off',
#   'time_samples': np.uint32(16),
#   'tsg_loss_h': np.float64(0.0),
#   'tsg_loss_h__unit': 'dB',
#   'tsg_loss_ldrh': np.float64(0.0),
#   'tsg_loss_ldrh__unit': 'dB',
#   'tsg_loss_ldrv': np.float64(11.4),
#   'tsg_loss_ldrv__unit': 'dB',
#   'tsg_loss_v': np.float64(0.0),
#   'tsg_loss_v__unit': 'dB',
#   'tx_loss_h': np.float64(4.93),
#   'tx_loss_h__unit': 'dB',
#   'tx_loss_ldrh': np.float64(1.92),
#   'tx_loss_ldrh__unit': 'dB',
#   'tx_loss_ldrv': np.float64(1.6),
#   'tx_loss_ldrv__unit': 'dB',
#   'tx_loss_v': np.float64(4.79),
#   'tx_loss_v__unit': 'dB',
#   'txd_peak_power': np.float64(217.771),
#   'txd_peak_power__unit': 'kW',
#   'unambiguous_velocity': np.float64(47.2413),
#   'unambiguous_velocity__unit': 'm/s',
#   'unfolding': np.uint32(2),
#   'unfolding_str': '3/4',
#   'zdr1_offset': np.float64(0.0),
#   'zdr1_offset__unit': 'dB',
#   'zdr_offset': np.float64(-0.42),
#   'zdr_offset__unit': 'dB',
#   'bin_range': np.float64(500.0),
#   'zero_index': np.int64(118),
#   'az': array([  0.5,   1.5,   2.5,   3.5,   4.5,   5.5,   6.5,   7.6,   8.6,
#            9.5,  10.5,  11.5,  12.5,  13.5,  14.5,  15.5,  16.5,  17.5,
#           18.5,  19.5,  20.5,  21.5,  22.5,  23.5,  24.5,  25.5,  26.6,
#           27.5,  28.5,  29.5,  30.5,  31.5,  32.5,  33.5,  34.5,  35.5,
#           36.5,  37.5,  38.5,  39.5,  40.5,  41.5,  42.5,  43.5,  44.5,
#           45.5,  46.5,  47.5,  48.5,  49.6,  50.6,  51.5,  52.5,  53.5,
#           54.5,  55.5,  56.5,  57.5,  58.5,  59.5,  60.5,  61.5,  62.5,
#           63.5,  64.5,  65.5,  66.5,  67.5,  68.6,  69.6,  70.5,  71.5,
#           72.5,  73.5,  74.5,  75.5,  76.5,  77.5,  78.5,  79.5,  80.5,
#           81.5,  82.5,  83.5,  84.5,  85.5,  86.5,  87.5,  88.5,  89.5,
#           90.5,  91.5,  92.5,  93.5,  94.5,  95.5,  96.5,  97.5,  98.5,
#           99.5, 100.5, 101.5, 102.5, 103.5, 104.5, 105.5, 106.5, 107.5,
#          108.5, 109.5, 110.5, 111.5, 112.5, 113.5, 114.5, 115.5, 116.5,
#          117.5, 118.5, 119.5, 120.5, 121.5, 122.5, 123.5, 124.5, 125.5,
#          126.5, 127.5, 128.5, 129.5, 130.5, 131.5, 132.5, 133.5, 134.5,
#          135.5, 136.5, 137.5, 138.5, 139.5, 140.5, 141.5, 142.5, 143.5,
#          144.5, 145.5, 146.5, 147.5, 148.5, 149.5, 150.5, 151.5, 152.5,
#          153.5, 154.6, 155.5, 156.5, 157.5, 158.5, 159.5, 160.5, 161.5,
#          162.5, 163.6, 164.5, 165.5, 166.5, 167.5, 168.5, 169.5, 170.5,
#          171.5, 172.5, 173.5, 174.5, 175.5, 176.6, 177.5, 178.5, 179.5,
#          180.5, 181.5, 182.5, 183.5, 184.5, 185.5, 186.5, 187.5, 188.5,
#          189.5, 190.5, 191.5, 192.5, 193.5, 194.5, 195.5, 196.6, 197.5,
#          198.5, 199.6, 200.5, 201.5, 202.5, 203.5, 204.5, 205.6, 206.6,
#          207.5, 208.5, 209.5, 210.5, 211.5, 212.5, 213.5, 214.5, 215.5,
#          216.6, 217.5, 218.6, 219.5, 220.5, 221.5, 222.5, 223.5, 224.5,
#          225.5, 226.5, 227.5, 228.5, 229.6, 230.5, 231.5, 232.5, 233.5,
#          234.5, 235.5, 236.5, 237.5, 238.5, 239.5, 240.5, 241.5, 242.5,
#          242.5, 243.5, 244.5, 245.5, 246.5, 247.5, 248.5, 249.5, 250.5,
#          251.5, 252.5, 253.5, 254.5, 255.5, 256.5, 257.5, 258.5, 259.5,
#          260.5, 261.5, 262.5, 263.5, 264.5, 265.5, 266.5, 267.5, 268.5,
#          269.5, 270.5, 271.5, 272.5, 273.6, 274.5, 275.5, 276.5, 277.5,
#          278.5, 279.5, 280.5, 281.5, 282.5, 283.5, 284.5, 285.5, 286.5,
#          287.5, 288.5, 289.5, 290.5, 291.5, 292.5, 293.5, 294.5, 295.5,
#          296.5, 297.5, 298.5, 299.5, 300.5, 301.5, 302.5, 303.5, 304.5,
#          305.5, 306.5, 307.5, 308.5, 309.5, 310.5, 311.5, 312.5, 313.5,
#          314.6, 315.5, 316.5, 317.5, 318.5, 319.5, 320.5, 321.5, 322.5,
#          323.5, 324.5, 325.5, 326.5, 327.5, 328.5, 329.5, 330.5, 331.5,
#          332.5, 333.5, 334.5, 335.5, 336.5, 337.5, 338.5, 339.5, 340.5,
#          341.5, 342.5, 343.5, 344.5, 345.6, 346.5, 347.5, 348.5, 349.5,
#          350.5, 351.5, 352.5, 353.5, 354.5, 355.5, 356.5, 357.5, 358.5,
#          359.5]),
#   'el': np.float64(0.4010009765625),
#   'r': array([   500.,   1000.,   1500.,   2000.,   2500.,   3000.,   3500.,
#            4000.,   4500.,   5000.,   5500.,   6000.,   6500.,   7000.,
#            7500.,   8000.,   8500.,   9000.,   9500.,  10000.,  10500.,
#           11000.,  11500.,  12000.,  12500.,  13000.,  13500.,  14000.,
#           14500.,  15000.,  15500.,  16000.,  16500.,  17000.,  17500.,
#           18000.,  18500.,  19000.,  19500.,  20000.,  20500.,  21000.,
#           21500.,  22000.,  22500.,  23000.,  23500.,  24000.,  24500.,
#           25000.,  25500.,  26000.,  26500.,  27000.,  27500.,  28000.,
#           28500.,  29000.,  29500.,  30000.,  30500.,  31000.,  31500.,
#           32000.,  32500.,  33000.,  33500.,  34000.,  34500.,  35000.,
#           35500.,  36000.,  36500.,  37000.,  37500.,  38000.,  38500.,
#           39000.,  39500.,  40000.,  40500.,  41000.,  41500.,  42000.,
#           42500.,  43000.,  43500.,  44000.,  44500.,  45000.,  45500.,
#           46000.,  46500.,  47000.,  47500.,  48000.,  48500.,  49000.,
#           49500.,  50000.,  50500.,  51000.,  51500.,  52000.,  52500.,
#           53000.,  53500.,  54000.,  54500.,  55000.,  55500.,  56000.,
#           56500.,  57000.,  57500.,  58000.,  58500.,  59000.,  59500.,
#           60000.,  60500.,  61000.,  61500.,  62000.,  62500.,  63000.,
#           63500.,  64000.,  64500.,  65000.,  65500.,  66000.,  66500.,
#           67000.,  67500.,  68000.,  68500.,  69000.,  69500.,  70000.,
#           70500.,  71000.,  71500.,  72000.,  72500.,  73000.,  73500.,
#           74000.,  74500.,  75000.,  75500.,  76000.,  76500.,  77000.,
#           77500.,  78000.,  78500.,  79000.,  79500.,  80000.,  80500.,
#           81000.,  81500.,  82000.,  82500.,  83000.,  83500.,  84000.,
#           84500.,  85000.,  85500.,  86000.,  86500.,  87000.,  87500.,
#           88000.,  88500.,  89000.,  89500.,  90000.,  90500.,  91000.,
#           91500.,  92000.,  92500.,  93000.,  93500.,  94000.,  94500.,
#           95000.,  95500.,  96000.,  96500.,  97000.,  97500.,  98000.,
#           98500.,  99000.,  99500., 100000., 100500., 101000., 101500.,
#          102000., 102500., 103000., 103500., 104000., 104500., 105000.,
#          105500., 106000., 106500., 107000., 107500., 108000., 108500.,
#          109000., 109500., 110000., 110500., 111000., 111500., 112000.,
#          112500., 113000., 113500., 114000., 114500., 115000., 115500.,
#          116000., 116500., 117000., 117500., 118000., 118500., 119000.,
#          119500., 120000.]),
#   'Time': '2024-08-14T00:00:01.623Z',
#   'max_range': np.float64(120000.0)},
#  'SCAN1': {'PRF': np.uint32(1180),
#   'adc_hh_temperature': np.float64(58.0),
#   'adc_hh_temperature__unit': 'degC',
#   'adc_hl_temperature': np.float64(56.0),
#   'adc_hl_temperature__unit': 'degC',
#   'adc_vh_temperature': np.float64(56.0),
#   'adc_vh_temperature__unit': 'degC',
#   'adc_vl_temperature': np.float64(58.0),
#   'adc_vl_temperature__unit': 'degC',
#   'angle_step': np.float64(1.0),
#   'angle_sync': np.uint8(1),
#   'ant_gain_h': np.float64(45.7),
#   'ant_gain_h__unit': 'dB',
#   'ant_gain_ldrh': np.float64(45.7),
#   'ant_gain_ldrh__unit': 'dB',
#   'ant_gain_ldrv': np.float64(43.0),
#   'ant_gain_ldrv__unit': 'dB',
#   'ant_gain_v': np.float64(45.8),
#   'ant_gain_v__unit': 'dB',
#   'azi_start': np.float64(0.0),
#   'azi_stop': np.float64(0.0),
#   'bin_count': np.uint32(240),
#   'clutter_filter_number': np.uint32(4),
#   'cpu_temp_0': np.float64(34.0),
#   'cpu_temp_0__unit': 'degC',
#   'cpu_temp_1': np.float64(0.0),
#   'cpu_temp_1__unit': 'degC',
#   'cpu_temp_2': np.float64(0.0),
#   'cpu_temp_2__unit': 'degC',
#   'cpu_temp_3': np.float64(0.0),
#   'cpu_temp_3__unit': 'degC',
#   'dbm0_h': np.float64(-106.231),
#   'dbm0_h__unit': 'dB',
#   'dbm0_v': np.float64(-105.436),
#   'dbm0_v__unit': 'dB',
#   'dbz0_h': np.float64(-35.1336),
#   'dbz0_h__unit': 'dBZ',
#   'dbz0_v': np.float64(-34.679),
#   'dbz0_v__unit': 'dBZ',
#   'elevation': np.float64(1.0986328125),
#   'gas_attenuation': np.float64(0.016),
#   'gas_attenuation__unit': 'dB/km',
#   'ldr_offset': np.float64(0.0),
#   'ldr_offset__unit': 'dB',
#   'malfunc': np.uint8(0),
#   'mb_temp_0': np.float64(31.0),
#   'mb_temp_0__unit': 'degC',
#   'mb_temp_1': np.float64(0.0),
#   'mb_temp_1__unit': 'degC',
#   'mb_temp_2': np.float64(0.0),
#   'mb_temp_2__unit': 'degC',
#   'mb_temp_3': np.float64(0.0),
#   'mb_temp_3__unit': 'degC',
#   'noise_power_h': np.float64(2.10011),
#   'noise_power_h__unit': 'dB',
#   'noise_power_v': np.float64(2.96022),
#   'noise_power_v__unit': 'dB',
#   'noise_threshold': np.float64(0.0),
#   'noise_threshold__unit': 'dB',
#   'nyquist_velocity': np.float64(15.7471),
#   'nyquist_velocity__unit': 'm/s',
#   'phidp_offset': np.float64(0.0),
#   'phidp_offset__unit': 'deg',
#   'pulse_width_number': '4',
#   'pulse_width_us': np.float64(0.8050000071525574),
#   'pulse_width_us_0': np.float64(0.4),
#   'pulse_width_us_0__unit': 'us',
#   'pulse_width_us_1': np.float64(0.805),
#   'pulse_width_us_1__unit': 'us',
#   'pulse_width_us_2': np.float64(1.0),
#   'pulse_width_us_2__unit': 'us',
#   'pulse_width_us_3': np.float64(2.0),
#   'pulse_width_us_3__unit': 'us',
#   'radar_wave_length': np.float64(0.053380001336336136),
#   'range': np.float64(120000.0),
#   'range_samples': np.uint32(4),
#   'range_start': np.float64(0.0),
#   'range_step': np.float64(125.0),
#   'raster': 'off',
#   'ray_count': np.uint32(361),
#   'rx_loss_h': np.float64(3.59),
#   'rx_loss_h__unit': 'dB',
#   'rx_loss_ldrh': np.float64(3.59),
#   'rx_loss_ldrh__unit': 'dB',
#   'rx_loss_ldrv': np.float64(4.1),
#   'rx_loss_ldrv__unit': 'dB',
#   'rx_loss_v': np.float64(4.11),
#   'rx_loss_v__unit': 'dB',
#   'scan_speed': np.float64(28.0),
#   'swap_phidp': 'off',
#   'time_samples': np.uint32(16),
#   'tsg_loss_h': np.float64(0.0),
#   'tsg_loss_h__unit': 'dB',
#   'tsg_loss_ldrh': np.float64(0.0),
#   'tsg_loss_ldrh__unit': 'dB',
#   'tsg_loss_ldrv': np.float64(11.4),
#   'tsg_loss_ldrv__unit': 'dB',
#   'tsg_loss_v': np.float64(0.0),
#   'tsg_loss_v__unit': 'dB',
#   'tx_loss_h': np.float64(4.93),
#   'tx_loss_h__unit': 'dB',
#   'tx_loss_ldrh': np.float64(1.92),
#   'tx_loss_ldrh__unit': 'dB',
#   'tx_loss_ldrv': np.float64(1.6),
#   'tx_loss_ldrv__unit': 'dB',
#   'tx_loss_v': np.float64(4.79),
#   'tx_loss_v__unit': 'dB',
#   'txd_peak_power': np.float64(217.771),
#   'txd_peak_power__unit': 'kW',
#   'unambiguous_velocity': np.float64(47.2413),
#   'unambiguous_velocity__unit': 'm/s',
#   'unfolding': np.uint32(2),
#   'unfolding_str': '3/4',
#   'zdr1_offset': np.float64(0.0),
#   'zdr1_offset__unit': 'dB',
#   'zdr_offset': np.float64(-0.42),
#   'zdr_offset__unit': 'dB',
#   'bin_range': np.float64(500.0),
#   'zero_index': np.int64(100),
#   'az': array([  0.5,   1.5,   2.5,   3.5,   4.5,   5.5,   6.6,   7.6,   8.5,
#            9.5,  10.5,  11.5,  12.5,  13.5,  14.5,  15.5,  16.5,  17.5,
#           18.5,  19.5,  20.5,  21.5,  22.5,  23.5,  24.5,  25.5,  26.5,
#           27.5,  28.5,  29.5,  30.5,  31.5,  32.5,  33.5,  34.5,  35.5,
#           36.5,  37.5,  38.5,  39.5,  40.5,  41.5,  42.5,  43.5,  44.5,
#           45.5,  46.6,  47.6,  48.6,  49.6,  50.5,  51.6,  52.5,  53.5,
#           54.5,  55.5,  56.5,  57.5,  58.5,  59.5,  60.5,  61.5,  62.5,
#           63.5,  64.5,  65.5,  66.5,  67.5,  68.5,  69.5,  70.5,  71.5,
#           72.5,  73.5,  74.5,  75.5,  76.5,  77.5,  78.5,  79.5,  80.5,
#           81.5,  82.5,  83.5,  84.5,  85.5,  86.5,  87.5,  88.5,  89.5,
#           90.5,  91.6,  92.5,  93.5,  94.5,  95.5,  96.5,  97.5,  98.5,
#           99.5, 100.5, 101.6, 102.5, 103.5, 104.5, 105.5, 106.5, 107.5,
#          108.5, 109.5, 110.5, 111.5, 112.5, 113.5, 114.5, 115.5, 116.5,
#          117.5, 118.5, 119.5, 120.5, 121.5, 122.5, 123.5, 124.5, 125.5,
#          126.5, 127.5, 128.5, 129.5, 130.6, 131.6, 132.6, 133.6, 134.5,
#          135.5, 136.5, 137.5, 138.5, 139.5, 140.5, 141.5, 142.5, 143.5,
#          144.5, 145.5, 146.5, 147.5, 148.5, 149.5, 150.5, 151.5, 152.5,
#          153.5, 154.5, 155.5, 156.5, 157.5, 158.5, 159.5, 160.5, 161.5,
#          162.5, 163.5, 164.5, 165.5, 166.5, 167.5, 168.5, 169.5, 170.5,
#          171.5, 172.5, 173.5, 174.5, 175.5, 176.6, 177.5, 178.5, 179.5,
#          180.5, 181.5, 182.5, 183.5, 184.5, 185.5, 186.5, 187.5, 188.5,
#          189.5, 190.5, 191.5, 192.5, 193.5, 194.5, 195.5, 196.5, 197.5,
#          198.5, 199.5, 200.5, 201.5, 202.5, 203.5, 204.5, 205.5, 206.5,
#          207.5, 208.5, 209.5, 210.5, 211.5, 212.5, 213.5, 214.5, 215.6,
#          216.5, 217.5, 218.5, 219.5, 220.5, 221.5, 222.5, 223.5, 224.5,
#          225.5, 226.5, 227.5, 228.5, 229.5, 230.5, 231.5, 232.5, 233.5,
#          234.5, 235.5, 236.5, 237.6, 238.5, 239.5, 240.5, 241.5, 242.5,
#          243.5, 244.5, 245.5, 246.5, 247.5, 248.5, 249.5, 250.5, 251.5,
#          252.5, 253.5, 254.5, 255.5, 256.5, 257.5, 258.5, 259.5, 260.5,
#          260.6, 261.5, 262.5, 263.5, 264.5, 265.5, 266.5, 267.5, 268.5,
#          269.5, 270.5, 271.5, 272.5, 273.5, 274.5, 275.5, 276.5, 277.5,
#          278.5, 279.5, 280.5, 281.5, 282.5, 283.5, 284.5, 285.5, 286.5,
#          287.5, 288.5, 289.5, 290.5, 291.5, 292.5, 293.5, 294.5, 295.5,
#          296.5, 297.5, 298.5, 299.5, 300.5, 301.5, 302.5, 303.5, 304.5,
#          305.5, 306.5, 307.5, 308.5, 309.5, 310.5, 311.5, 312.5, 313.5,
#          314.5, 315.5, 316.5, 317.5, 318.5, 319.5, 320.5, 321.5, 322.5,
#          323.5, 324.5, 325.5, 326.5, 327.5, 328.5, 329.5, 330.5, 331.5,
#          332.5, 333.5, 334.5, 335.5, 336.5, 337.5, 338.5, 339.5, 340.5,
#          341.5, 342.5, 343.5, 344.5, 345.5, 346.5, 347.5, 348.5, 349.5,
#          350.5, 351.5, 352.5, 353.5, 354.5, 355.5, 356.5, 357.5, 358.5,
#          359.5]),
#   'el': np.float64(1.0986328125),
#   'r': array([   500.,   1000.,   1500.,   2000.,   2500.,   3000.,   3500.,
#            4000.,   4500.,   5000.,   5500.,   6000.,   6500.,   7000.,
#            7500.,   8000.,   8500.,   9000.,   9500.,  10000.,  10500.,
#           11000.,  11500.,  12000.,  12500.,  13000.,  13500.,  14000.,
#           14500.,  15000.,  15500.,  16000.,  16500.,  17000.,  17500.,
#           18000.,  18500.,  19000.,  19500.,  20000.,  20500.,  21000.,
#           21500.,  22000.,  22500.,  23000.,  23500.,  24000.,  24500.,
#           25000.,  25500.,  26000.,  26500.,  27000.,  27500.,  28000.,
#           28500.,  29000.,  29500.,  30000.,  30500.,  31000.,  31500.,
#           32000.,  32500.,  33000.,  33500.,  34000.,  34500.,  35000.,
#           35500.,  36000.,  36500.,  37000.,  37500.,  38000.,  38500.,
#           39000.,  39500.,  40000.,  40500.,  41000.,  41500.,  42000.,
#           42500.,  43000.,  43500.,  44000.,  44500.,  45000.,  45500.,
#           46000.,  46500.,  47000.,  47500.,  48000.,  48500.,  49000.,
#           49500.,  50000.,  50500.,  51000.,  51500.,  52000.,  52500.,
#           53000.,  53500.,  54000.,  54500.,  55000.,  55500.,  56000.,
#           56500.,  57000.,  57500.,  58000.,  58500.,  59000.,  59500.,
#           60000.,  60500.,  61000.,  61500.,  62000.,  62500.,  63000.,
#           63500.,  64000.,  64500.,  65000.,  65500.,  66000.,  66500.,
#           67000.,  67500.,  68000.,  68500.,  69000.,  69500.,  70000.,
#           70500.,  71000.,  71500.,  72000.,  72500.,  73000.,  73500.,
#           74000.,  74500.,  75000.,  75500.,  76000.,  76500.,  77000.,
#           77500.,  78000.,  78500.,  79000.,  79500.,  80000.,  80500.,
#           81000.,  81500.,  82000.,  82500.,  83000.,  83500.,  84000.,
#           84500.,  85000.,  85500.,  86000.,  86500.,  87000.,  87500.,
#           88000.,  88500.,  89000.,  89500.,  90000.,  90500.,  91000.,
#           91500.,  92000.,  92500.,  93000.,  93500.,  94000.,  94500.,
#           95000.,  95500.,  96000.,  96500.,  97000.,  97500.,  98000.,
#           98500.,  99000.,  99500., 100000., 100500., 101000., 101500.,
#          102000., 102500., 103000., 103500., 104000., 104500., 105000.,
#          105500., 106000., 106500., 107000., 107500., 108000., 108500.,
#          109000., 109500., 110000., 110500., 111000., 111500., 112000.,
#          112500., 113000., 113500., 114000., 114500., 115000., 115500.,
#          116000., 116500., 117000., 117500., 118000., 118500., 119000.,
#          119500., 120000.]),
#   'Time': '2024-08-14T00:00:15.124Z',
#   'max_range': np.float64(120000.0)},
#  'SCAN10': {'PRF': np.uint32(1180),
#   'adc_hh_temperature': np.float64(58.0),
#   'adc_hh_temperature__unit': 'degC',
#   'adc_hl_temperature': np.float64(56.0),
#   'adc_hl_temperature__unit': 'degC',
#   'adc_vh_temperature': np.float64(55.0),
#   'adc_vh_temperature__unit': 'degC',
#   'adc_vl_temperature': np.float64(58.0),
#   'adc_vl_temperature__unit': 'degC',
#   'angle_step': np.float64(1.0),
#   'angle_sync': np.uint8(1),
#   'ant_gain_h': np.float64(45.7),
#   'ant_gain_h__unit': 'dB',
#   'ant_gain_ldrh': np.float64(45.7),
#   'ant_gain_ldrh__unit': 'dB',
#   'ant_gain_ldrv': np.float64(43.0),
#   'ant_gain_ldrv__unit': 'dB',
#   'ant_gain_v': np.float64(45.8),
#   'ant_gain_v__unit': 'dB',
#   'azi_start': np.float64(0.0),
#   'azi_stop': np.float64(0.0),
#   'bin_count': np.uint32(160),
#   'clutter_filter_number': np.uint32(4),
#   'cpu_temp_0': np.float64(34.0),
#   'cpu_temp_0__unit': 'degC',
#   'cpu_temp_1': np.float64(0.0),
#   'cpu_temp_1__unit': 'degC',
#   'cpu_temp_2': np.float64(0.0),
#   'cpu_temp_2__unit': 'degC',
#   'cpu_temp_3': np.float64(0.0),
#   'cpu_temp_3__unit': 'degC',
#   'dbm0_h': np.float64(-106.231),
#   'dbm0_h__unit': 'dB',
#   'dbm0_v': np.float64(-105.436),
#   'dbm0_v__unit': 'dB',
#   'dbz0_h': np.float64(-35.1336),
#   'dbz0_h__unit': 'dBZ',
#   'dbz0_v': np.float64(-34.679),
#   'dbz0_v__unit': 'dBZ',
#   'elevation': np.float64(16.0015869140625),
#   'gas_attenuation': np.float64(0.016),
#   'gas_attenuation__unit': 'dB/km',
#   'ldr_offset': np.float64(0.0),
#   'ldr_offset__unit': 'dB',
#   'malfunc': np.uint8(0),
#   'mb_temp_0': np.float64(31.0),
#   'mb_temp_0__unit': 'degC',
#   'mb_temp_1': np.float64(0.0),
#   'mb_temp_1__unit': 'degC',
#   'mb_temp_2': np.float64(0.0),
#   'mb_temp_2__unit': 'degC',
#   'mb_temp_3': np.float64(0.0),
#   'mb_temp_3__unit': 'degC',
#   'noise_power_h': np.float64(2.10011),
#   'noise_power_h__unit': 'dB',
#   'noise_power_v': np.float64(2.96022),
#   'noise_power_v__unit': 'dB',
#   'noise_threshold': np.float64(0.0),
#   'noise_threshold__unit': 'dB',
#   'nyquist_velocity': np.float64(15.7471),
#   'nyquist_velocity__unit': 'm/s',
#   'phidp_offset': np.float64(0.0),
#   'phidp_offset__unit': 'deg',
#   'pulse_width_number': '4',
#   'pulse_width_us': np.float64(0.8050000071525574),
#   'pulse_width_us_0': np.float64(0.4),
#   'pulse_width_us_0__unit': 'us',
#   'pulse_width_us_1': np.float64(0.805),
#   'pulse_width_us_1__unit': 'us',
#   'pulse_width_us_2': np.float64(1.0),
#   'pulse_width_us_2__unit': 'us',
#   'pulse_width_us_3': np.float64(2.0),
#   'pulse_width_us_3__unit': 'us',
#   'radar_wave_length': np.float64(0.053380001336336136),
#   'range': np.float64(80000.0),
#   'range_samples': np.uint32(4),
#   'range_start': np.float64(0.0),
#   'range_step': np.float64(125.0),
#   'raster': 'off',
#   'ray_count': np.uint32(360),
#   'rx_loss_h': np.float64(3.59),
#   'rx_loss_h__unit': 'dB',
#   'rx_loss_ldrh': np.float64(3.59),
#   'rx_loss_ldrh__unit': 'dB',
#   'rx_loss_ldrv': np.float64(4.1),
#   'rx_loss_ldrv__unit': 'dB',
#   'rx_loss_v': np.float64(4.11),
#   'rx_loss_v__unit': 'dB',
#   'scan_speed': np.float64(30.0),
#   'swap_phidp': 'off',
#   'time_samples': np.uint32(16),
#   'tsg_loss_h': np.float64(0.0),
#   'tsg_loss_h__unit': 'dB',
#   'tsg_loss_ldrh': np.float64(0.0),
#   'tsg_loss_ldrh__unit': 'dB',
#   'tsg_loss_ldrv': np.float64(11.4),
#   'tsg_loss_ldrv__unit': 'dB',
#   'tsg_loss_v': np.float64(0.0),
#   'tsg_loss_v__unit': 'dB',
#   'tx_loss_h': np.float64(4.93),
#   'tx_loss_h__unit': 'dB',
#   'tx_loss_ldrh': np.float64(1.92),
#   'tx_loss_ldrh__unit': 'dB',
#   'tx_loss_ldrv': np.float64(1.6),
#   'tx_loss_ldrv__unit': 'dB',
#   'tx_loss_v': np.float64(4.79),
#   'tx_loss_v__unit': 'dB',
#   'txd_peak_power': np.float64(217.771),
#   'txd_peak_power__unit': 'kW',
#   'unambiguous_velocity': np.float64(47.2413),
#   'unambiguous_velocity__unit': 'm/s',
#   'unfolding': np.uint32(2),
#   'unfolding_str': '3/4',
#   'zdr1_offset': np.float64(0.0),
#   'zdr1_offset__unit': 'dB',
#   'zdr_offset': np.float64(-0.42),
#   'zdr_offset__unit': 'dB',
#   'bin_range': np.float64(500.0),
#   'zero_index': np.int64(222),
#   'az': array([  0.5,   1.5,   2.5,   3.5,   4.5,   5.5,   6.5,   7.5,   8.5,
#            9.5,  10.5,  11.5,  12.5,  13.5,  14.5,  15.5,  16.5,  17.6,
#           18.6,  19.5,  20.5,  21.5,  22.5,  23.5,  24.5,  25.5,  26.5,
#           27.5,  28.5,  29.5,  30.5,  31.5,  32.5,  33.5,  34.5,  35.5,
#           36.5,  37.5,  38.5,  39.5,  40.5,  41.5,  42.5,  43.5,  44.5,
#           45.5,  46.5,  47.5,  48.5,  49.5,  50.5,  51.5,  52.5,  53.5,
#           54.5,  55.5,  56.6,  57.5,  58.5,  59.5,  60.6,  61.5,  62.5,
#           63.6,  64.5,  65.5,  66.5,  67.5,  68.5,  69.5,  70.5,  71.5,
#           72.5,  73.5,  74.6,  75.5,  76.5,  77.5,  78.5,  79.5,  80.5,
#           81.5,  82.5,  83.5,  84.5,  85.5,  86.5,  87.5,  88.5,  89.5,
#           90.5,  91.5,  92.5,  93.5,  94.5,  95.5,  96.5,  97.5,  98.5,
#           99.5, 100.6, 101.5, 102.5, 103.5, 104.5, 105.5, 106.5, 107.6,
#          108.6, 109.5, 110.5, 111.5, 112.5, 113.5, 114.5, 115.5, 116.5,
#          117.5, 118.5, 119.5, 120.5, 121.5, 122.5, 123.5, 124.5, 125.5,
#          126.5, 127.5, 128.5, 129.5, 130.5, 131.5, 132.5, 133.5, 134.5,
#          135.5, 136.5, 137.5, 138.5, 139.5, 140.5, 141.5, 142.5, 143.5,
#          144.5, 145.5, 146.6, 147.5, 148.5, 149.5, 150.5, 151.5, 152.5,
#          153.5, 154.5, 155.5, 156.5, 157.5, 158.5, 159.5, 160.5, 161.5,
#          162.5, 163.5, 164.5, 165.5, 166.5, 167.5, 168.5, 169.5, 170.5,
#          171.5, 172.5, 173.5, 174.5, 175.5, 176.5, 177.5, 178.5, 179.5,
#          180.5, 181.5, 182.5, 183.5, 184.5, 185.5, 186.5, 187.5, 188.5,
#          189.5, 190.5, 191.5, 192.5, 193.5, 194.5, 195.5, 196.5, 197.5,
#          198.6, 199.5, 200.5, 201.5, 202.5, 203.5, 204.5, 205.5, 206.5,
#          207.5, 208.5, 209.5, 210.5, 211.5, 212.5, 213.5, 214.5, 215.5,
#          216.5, 217.5, 218.5, 219.5, 220.5, 221.5, 222.5, 223.5, 224.5,
#          225.5, 226.5, 227.5, 228.5, 229.5, 230.5, 231.5, 232.5, 233.5,
#          234.5, 235.5, 236.5, 237.5, 238.5, 239.5, 240.5, 241.5, 242.5,
#          243.5, 244.5, 245.5, 246.5, 247.5, 248.5, 249.5, 250.5, 251.5,
#          252.5, 253.5, 254.5, 255.5, 256.5, 257.5, 258.5, 259.5, 260.5,
#          261.5, 262.5, 263.5, 264.5, 265.5, 266.5, 267.5, 268.5, 269.5,
#          270.5, 271.5, 272.5, 273.5, 274.5, 275.5, 276.5, 277.5, 278.5,
#          279.5, 280.6, 281.5, 282.5, 283.5, 284.5, 285.5, 286.5, 287.6,
#          288.6, 289.5, 290.5, 291.5, 292.5, 293.5, 294.5, 295.5, 296.5,
#          297.5, 298.5, 299.5, 300.5, 301.5, 302.5, 303.5, 304.5, 305.5,
#          306.5, 307.5, 308.5, 309.5, 310.5, 311.5, 312.5, 313.5, 314.5,
#          315.5, 316.5, 317.5, 318.5, 319.5, 320.5, 321.5, 322.6, 323.5,
#          324.5, 325.6, 326.6, 327.5, 328.5, 329.5, 330.5, 331.5, 332.6,
#          333.6, 334.5, 335.5, 336.5, 337.5, 338.5, 339.5, 340.5, 341.5,
#          342.5, 343.5, 344.6, 345.5, 346.5, 347.5, 348.5, 349.5, 350.5,
#          351.5, 352.5, 353.5, 354.5, 355.5, 356.5, 357.5, 358.5, 359.5]),
#   'el': np.float64(16.0015869140625),
#   'r': array([  500.,  1000.,  1500.,  2000.,  2500.,  3000.,  3500.,  4000.,
#           4500.,  5000.,  5500.,  6000.,  6500.,  7000.,  7500.,  8000.,
#           8500.,  9000.,  9500., 10000., 10500., 11000., 11500., 12000.,
#          12500., 13000., 13500., 14000., 14500., 15000., 15500., 16000.,
#          16500., 17000., 17500., 18000., 18500., 19000., 19500., 20000.,
#          20500., 21000., 21500., 22000., 22500., 23000., 23500., 24000.,
#          24500., 25000., 25500., 26000., 26500., 27000., 27500., 28000.,
#          28500., 29000., 29500., 30000., 30500., 31000., 31500., 32000.,
#          32500., 33000., 33500., 34000., 34500., 35000., 35500., 36000.,
#          36500., 37000., 37500., 38000., 38500., 39000., 39500., 40000.,
#          40500., 41000., 41500., 42000., 42500., 43000., 43500., 44000.,
#          44500., 45000., 45500., 46000., 46500., 47000., 47500., 48000.,
#          48500., 49000., 49500., 50000., 50500., 51000., 51500., 52000.,
#          52500., 53000., 53500., 54000., 54500., 55000., 55500., 56000.,
#          56500., 57000., 57500., 58000., 58500., 59000., 59500., 60000.,
#          60500., 61000., 61500., 62000., 62500., 63000., 63500., 64000.,
#          64500., 65000., 65500., 66000., 66500., 67000., 67500., 68000.,
#          68500., 69000., 69500., 70000., 70500., 71000., 71500., 72000.,
#          72500., 73000., 73500., 74000., 74500., 75000., 75500., 76000.,
#          76500., 77000., 77500., 78000., 78500., 79000., 79500., 80000.]),
#   'Time': '2024-08-14T00:02:12.837Z',
#   'max_range': np.float64(80000.0)},
#  'SCAN11': {'PRF': np.uint32(1180),
#   'adc_hh_temperature': np.float64(58.0),
#   'adc_hh_temperature__unit': 'degC',
#   'adc_hl_temperature': np.float64(56.0),
#   'adc_hl_temperature__unit': 'degC',
#   'adc_vh_temperature': np.float64(55.0),
#   'adc_vh_temperature__unit': 'degC',
#   'adc_vl_temperature': np.float64(58.0),
#   'adc_vl_temperature__unit': 'degC',
#   'angle_step': np.float64(1.0),
#   'angle_sync': np.uint8(1),
#   'ant_gain_h': np.float64(45.7),
#   'ant_gain_h__unit': 'dB',
#   'ant_gain_ldrh': np.float64(45.7),
#   'ant_gain_ldrh__unit': 'dB',
#   'ant_gain_ldrv': np.float64(43.0),
#   'ant_gain_ldrv__unit': 'dB',
#   'ant_gain_v': np.float64(45.8),
#   'ant_gain_v__unit': 'dB',
#   'azi_start': np.float64(0.0),
#   'azi_stop': np.float64(0.0),
#   'bin_count': np.uint32(160),
#   'clutter_filter_number': np.uint32(4),
#   'cpu_temp_0': np.float64(34.0),
#   'cpu_temp_0__unit': 'degC',
#   'cpu_temp_1': np.float64(0.0),
#   'cpu_temp_1__unit': 'degC',
#   'cpu_temp_2': np.float64(0.0),
#   'cpu_temp_2__unit': 'degC',
#   'cpu_temp_3': np.float64(0.0),
#   'cpu_temp_3__unit': 'degC',
#   'dbm0_h': np.float64(-106.231),
#   'dbm0_h__unit': 'dB',
#   'dbm0_v': np.float64(-105.436),
#   'dbm0_v__unit': 'dB',
#   'dbz0_h': np.float64(-35.1336),
#   'dbz0_h__unit': 'dBZ',
#   'dbz0_v': np.float64(-34.679),
#   'dbz0_v__unit': 'dBZ',
#   'elevation': np.float64(20.0006103515625),
#   'gas_attenuation': np.float64(0.016),
#   'gas_attenuation__unit': 'dB/km',
#   'ldr_offset': np.float64(0.0),
#   'ldr_offset__unit': 'dB',
#   'malfunc': np.uint8(0),
#   'mb_temp_0': np.float64(31.0),
#   'mb_temp_0__unit': 'degC',
#   'mb_temp_1': np.float64(0.0),
#   'mb_temp_1__unit': 'degC',
#   'mb_temp_2': np.float64(0.0),
#   'mb_temp_2__unit': 'degC',
#   'mb_temp_3': np.float64(0.0),
#   'mb_temp_3__unit': 'degC',
#   'noise_power_h': np.float64(2.10011),
#   'noise_power_h__unit': 'dB',
#   'noise_power_v': np.float64(2.96022),
#   'noise_power_v__unit': 'dB',
#   'noise_threshold': np.float64(0.0),
#   'noise_threshold__unit': 'dB',
#   'nyquist_velocity': np.float64(15.7471),
#   'nyquist_velocity__unit': 'm/s',
#   'phidp_offset': np.float64(0.0),
#   'phidp_offset__unit': 'deg',
#   'pulse_width_number': '4',
#   'pulse_width_us': np.float64(0.8050000071525574),
#   'pulse_width_us_0': np.float64(0.4),
#   'pulse_width_us_0__unit': 'us',
#   'pulse_width_us_1': np.float64(0.805),
#   'pulse_width_us_1__unit': 'us',
#   'pulse_width_us_2': np.float64(1.0),
#   'pulse_width_us_2__unit': 'us',
#   'pulse_width_us_3': np.float64(2.0),
#   'pulse_width_us_3__unit': 'us',
#   'radar_wave_length': np.float64(0.053380001336336136),
#   'range': np.float64(80000.0),
#   'range_samples': np.uint32(4),
#   'range_start': np.float64(0.0),
#   'range_step': np.float64(125.0),
#   'raster': 'off',
#   'ray_count': np.uint32(360),
#   'rx_loss_h': np.float64(3.59),
#   'rx_loss_h__unit': 'dB',
#   'rx_loss_ldrh': np.float64(3.59),
#   'rx_loss_ldrh__unit': 'dB',
#   'rx_loss_ldrv': np.float64(4.1),
#   'rx_loss_ldrv__unit': 'dB',
#   'rx_loss_v': np.float64(4.11),
#   'rx_loss_v__unit': 'dB',
#   'scan_speed': np.float64(30.0),
#   'swap_phidp': 'off',
#   'time_samples': np.uint32(16),
#   'tsg_loss_h': np.float64(0.0),
#   'tsg_loss_h__unit': 'dB',
#   'tsg_loss_ldrh': np.float64(0.0),
#   'tsg_loss_ldrh__unit': 'dB',
#   'tsg_loss_ldrv': np.float64(11.4),
#   'tsg_loss_ldrv__unit': 'dB',
#   'tsg_loss_v': np.float64(0.0),
#   'tsg_loss_v__unit': 'dB',
#   'tx_loss_h': np.float64(4.93),
#   'tx_loss_h__unit': 'dB',
#   'tx_loss_ldrh': np.float64(1.92),
#   'tx_loss_ldrh__unit': 'dB',
#   'tx_loss_ldrv': np.float64(1.6),
#   'tx_loss_ldrv__unit': 'dB',
#   'tx_loss_v': np.float64(4.79),
#   'tx_loss_v__unit': 'dB',
#   'txd_peak_power': np.float64(217.771),
#   'txd_peak_power__unit': 'kW',
#   'unambiguous_velocity': np.float64(47.2413),
#   'unambiguous_velocity__unit': 'm/s',
#   'unfolding': np.uint32(2),
#   'unfolding_str': '3/4',
#   'zdr1_offset': np.float64(0.0),
#   'zdr1_offset__unit': 'dB',
#   'zdr_offset': np.float64(-0.42),
#   'zdr_offset__unit': 'dB',
#   'bin_range': np.float64(500.0),
#   'zero_index': np.int64(182),
#   'az': array([  0.5,   1.5,   2.5,   3.5,   4.5,   5.5,   6.5,   7.5,   8.5,
#            9.5,  10.5,  11.5,  12.5,  13.5,  14.5,  15.5,  16.5,  17.5,
#           18.5,  19.5,  20.5,  21.5,  22.5,  23.5,  24.5,  25.5,  26.5,
#           27.5,  28.5,  29.5,  30.5,  31.5,  32.5,  33.5,  34.5,  35.5,
#           36.5,  37.5,  38.5,  39.5,  40.5,  41.5,  42.5,  43.5,  44.5,
#           45.5,  46.5,  47.5,  48.5,  49.5,  50.5,  51.5,  52.5,  53.5,
#           54.5,  55.5,  56.5,  57.5,  58.5,  59.5,  60.5,  61.6,  62.5,
#           63.5,  64.5,  65.5,  66.5,  67.5,  68.5,  69.5,  70.5,  71.6,
#           72.5,  73.5,  74.5,  75.5,  76.5,  77.5,  78.5,  79.5,  80.5,
#           81.5,  82.5,  83.5,  84.5,  85.5,  86.5,  87.5,  88.5,  89.5,
#           90.5,  91.5,  92.5,  93.5,  94.5,  95.5,  96.5,  97.5,  98.5,
#           99.5, 100.5, 101.5, 102.5, 103.5, 104.5, 105.5, 106.5, 107.5,
#          108.5, 109.5, 110.5, 111.5, 112.6, 113.5, 114.5, 115.5, 116.5,
#          117.5, 118.5, 119.5, 120.6, 121.5, 122.5, 123.5, 124.5, 125.5,
#          126.5, 127.5, 128.5, 129.5, 130.5, 131.5, 132.5, 133.5, 134.5,
#          135.5, 136.5, 137.5, 138.5, 139.5, 140.6, 141.5, 142.5, 143.5,
#          144.5, 145.5, 146.5, 147.5, 148.5, 149.5, 150.5, 151.5, 152.6,
#          153.5, 154.5, 155.5, 156.5, 157.6, 158.6, 159.5, 160.5, 161.5,
#          162.5, 163.5, 164.6, 165.6, 166.5, 167.5, 168.5, 169.5, 170.5,
#          171.5, 172.5, 173.5, 174.5, 175.5, 176.5, 177.5, 178.5, 179.5,
#          180.5, 181.5, 182.6, 183.5, 184.5, 185.5, 186.6, 187.5, 188.5,
#          189.5, 190.5, 191.5, 192.5, 193.5, 194.5, 195.5, 196.5, 197.5,
#          198.5, 199.5, 200.5, 201.5, 202.5, 203.5, 204.5, 205.5, 206.5,
#          207.5, 208.5, 209.5, 210.6, 211.5, 212.5, 213.5, 214.5, 215.5,
#          216.6, 217.5, 218.5, 219.5, 220.5, 221.5, 222.5, 223.5, 224.5,
#          225.5, 226.5, 227.5, 228.5, 229.5, 230.5, 231.5, 232.5, 233.5,
#          234.5, 235.5, 236.6, 237.5, 238.5, 239.5, 240.5, 241.5, 242.5,
#          243.5, 244.5, 245.5, 246.5, 247.5, 248.5, 249.5, 250.5, 251.5,
#          252.5, 253.5, 254.6, 255.5, 256.5, 257.5, 258.6, 259.5, 260.5,
#          261.5, 262.5, 263.5, 264.5, 265.5, 266.5, 267.5, 268.5, 269.5,
#          270.5, 271.5, 272.5, 273.5, 274.6, 275.5, 276.5, 277.5, 278.5,
#          279.5, 280.5, 281.5, 282.5, 283.5, 284.5, 285.5, 286.5, 287.5,
#          288.5, 289.5, 290.5, 291.5, 292.5, 293.5, 294.5, 295.6, 296.6,
#          297.5, 298.5, 299.5, 300.6, 301.5, 302.5, 303.5, 304.5, 305.5,
#          306.5, 307.5, 308.5, 309.5, 310.5, 311.5, 312.5, 313.5, 314.5,
#          315.5, 316.5, 317.5, 318.5, 319.5, 320.5, 321.5, 322.5, 323.5,
#          324.5, 325.5, 326.5, 327.5, 328.5, 329.5, 330.5, 331.5, 332.5,
#          333.5, 334.5, 335.5, 336.5, 337.5, 338.6, 339.5, 340.5, 341.5,
#          342.5, 343.5, 344.5, 345.5, 346.5, 347.5, 348.5, 349.5, 350.5,
#          351.5, 352.5, 353.5, 354.5, 355.5, 356.5, 357.5, 358.5, 359.5]),
#   'el': np.float64(20.0006103515625),
#   'r': array([  500.,  1000.,  1500.,  2000.,  2500.,  3000.,  3500.,  4000.,
#           4500.,  5000.,  5500.,  6000.,  6500.,  7000.,  7500.,  8000.,
#           8500.,  9000.,  9500., 10000., 10500., 11000., 11500., 12000.,
#          12500., 13000., 13500., 14000., 14500., 15000., 15500., 16000.,
#          16500., 17000., 17500., 18000., 18500., 19000., 19500., 20000.,
#          20500., 21000., 21500., 22000., 22500., 23000., 23500., 24000.,
#          24500., 25000., 25500., 26000., 26500., 27000., 27500., 28000.,
#          28500., 29000., 29500., 30000., 30500., 31000., 31500., 32000.,
#          32500., 33000., 33500., 34000., 34500., 35000., 35500., 36000.,
#          36500., 37000., 37500., 38000., 38500., 39000., 39500., 40000.,
#          40500., 41000., 41500., 42000., 42500., 43000., 43500., 44000.,
#          44500., 45000., 45500., 46000., 46500., 47000., 47500., 48000.,
#          48500., 49000., 49500., 50000., 50500., 51000., 51500., 52000.,
#          52500., 53000., 53500., 54000., 54500., 55000., 55500., 56000.,
#          56500., 57000., 57500., 58000., 58500., 59000., 59500., 60000.,
#          60500., 61000., 61500., 62000., 62500., 63000., 63500., 64000.,
#          64500., 65000., 65500., 66000., 66500., 67000., 67500., 68000.,
#          68500., 69000., 69500., 70000., 70500., 71000., 71500., 72000.,
#          72500., 73000., 73500., 74000., 74500., 75000., 75500., 76000.,
#          76500., 77000., 77500., 78000., 78500., 79000., 79500., 80000.]),
#   'Time': '2024-08-14T00:02:26.171Z',
#   'max_range': np.float64(80000.0)},
#  'SCAN12': {'PRF': np.uint32(1180),
#   'adc_hh_temperature': np.float64(58.0),
#   'adc_hh_temperature__unit': 'degC',
#   'adc_hl_temperature': np.float64(57.0),
#   'adc_hl_temperature__unit': 'degC',
#   'adc_vh_temperature': np.float64(56.0),
#   'adc_vh_temperature__unit': 'degC',
#   'adc_vl_temperature': np.float64(58.0),
#   'adc_vl_temperature__unit': 'degC',
#   'angle_step': np.float64(1.0),
#   'angle_sync': np.uint8(1),
#   'ant_gain_h': np.float64(45.7),
#   'ant_gain_h__unit': 'dB',
#   'ant_gain_ldrh': np.float64(45.7),
#   'ant_gain_ldrh__unit': 'dB',
#   'ant_gain_ldrv': np.float64(43.0),
#   'ant_gain_ldrv__unit': 'dB',
#   'ant_gain_v': np.float64(45.8),
#   'ant_gain_v__unit': 'dB',
#   'azi_start': np.float64(0.0),
#   'azi_stop': np.float64(0.0),
#   'bin_count': np.uint32(120),
#   'clutter_filter_number': np.uint32(4),
#   'cpu_temp_0': np.float64(34.0),
#   'cpu_temp_0__unit': 'degC',
#   'cpu_temp_1': np.float64(0.0),
#   'cpu_temp_1__unit': 'degC',
#   'cpu_temp_2': np.float64(0.0),
#   'cpu_temp_2__unit': 'degC',
#   'cpu_temp_3': np.float64(0.0),
#   'cpu_temp_3__unit': 'degC',
#   'dbm0_h': np.float64(-106.231),
#   'dbm0_h__unit': 'dB',
#   'dbm0_v': np.float64(-105.436),
#   'dbm0_v__unit': 'dB',
#   'dbz0_h': np.float64(-35.1336),
#   'dbz0_h__unit': 'dBZ',
#   'dbz0_v': np.float64(-34.679),
#   'dbz0_v__unit': 'dBZ',
#   'elevation': np.float64(23.9996337890625),
#   'gas_attenuation': np.float64(0.016),
#   'gas_attenuation__unit': 'dB/km',
#   'ldr_offset': np.float64(0.0),
#   'ldr_offset__unit': 'dB',
#   'malfunc': np.uint8(0),
#   'mb_temp_0': np.float64(31.0),
#   'mb_temp_0__unit': 'degC',
#   'mb_temp_1': np.float64(0.0),
#   'mb_temp_1__unit': 'degC',
#   'mb_temp_2': np.float64(0.0),
#   'mb_temp_2__unit': 'degC',
#   'mb_temp_3': np.float64(0.0),
#   'mb_temp_3__unit': 'degC',
#   'noise_power_h': np.float64(2.10011),
#   'noise_power_h__unit': 'dB',
#   'noise_power_v': np.float64(2.96022),
#   'noise_power_v__unit': 'dB',
#   'noise_threshold': np.float64(0.0),
#   'noise_threshold__unit': 'dB',
#   'nyquist_velocity': np.float64(15.7471),
#   'nyquist_velocity__unit': 'm/s',
#   'phidp_offset': np.float64(0.0),
#   'phidp_offset__unit': 'deg',
#   'pulse_width_number': '4',
#   'pulse_width_us': np.float64(0.8050000071525574),
#   'pulse_width_us_0': np.float64(0.4),
#   'pulse_width_us_0__unit': 'us',
#   'pulse_width_us_1': np.float64(0.805),
#   'pulse_width_us_1__unit': 'us',
#   'pulse_width_us_2': np.float64(1.0),
#   'pulse_width_us_2__unit': 'us',
#   'pulse_width_us_3': np.float64(2.0),
#   'pulse_width_us_3__unit': 'us',
#   'radar_wave_length': np.float64(0.053380001336336136),
#   'range': np.float64(60000.0),
#   'range_samples': np.uint32(4),
#   'range_start': np.float64(0.0),
#   'range_step': np.float64(125.0),
#   'raster': 'off',
#   'ray_count': np.uint32(361),
#   'rx_loss_h': np.float64(3.59),
#   'rx_loss_h__unit': 'dB',
#   'rx_loss_ldrh': np.float64(3.59),
#   'rx_loss_ldrh__unit': 'dB',
#   'rx_loss_ldrv': np.float64(4.1),
#   'rx_loss_ldrv__unit': 'dB',
#   'rx_loss_v': np.float64(4.11),
#   'rx_loss_v__unit': 'dB',
#   'scan_speed': np.float64(30.0),
#   'swap_phidp': 'off',
#   'time_samples': np.uint32(16),
#   'tsg_loss_h': np.float64(0.0),
#   'tsg_loss_h__unit': 'dB',
#   'tsg_loss_ldrh': np.float64(0.0),
#   'tsg_loss_ldrh__unit': 'dB',
#   'tsg_loss_ldrv': np.float64(11.4),
#   'tsg_loss_ldrv__unit': 'dB',
#   'tsg_loss_v': np.float64(0.0),
#   'tsg_loss_v__unit': 'dB',
#   'tx_loss_h': np.float64(4.93),
#   'tx_loss_h__unit': 'dB',
#   'tx_loss_ldrh': np.float64(1.92),
#   'tx_loss_ldrh__unit': 'dB',
#   'tx_loss_ldrv': np.float64(1.6),
#   'tx_loss_ldrv__unit': 'dB',
#   'tx_loss_v': np.float64(4.79),
#   'tx_loss_v__unit': 'dB',
#   'txd_peak_power': np.float64(217.771),
#   'txd_peak_power__unit': 'kW',
#   'unambiguous_velocity': np.float64(47.2413),
#   'unambiguous_velocity__unit': 'm/s',
#   'unfolding': np.uint32(2),
#   'unfolding_str': '3/4',
#   'zdr1_offset': np.float64(0.0),
#   'zdr1_offset__unit': 'dB',
#   'zdr_offset': np.float64(-0.42),
#   'zdr_offset__unit': 'dB',
#   'bin_range': np.float64(500.0),
#   'zero_index': np.int64(142),
#   'az': array([  0.5,   1.5,   2.5,   3.5,   4.5,   5.5,   6.5,   7.5,   8.5,
#            9.5,  10.5,  11.5,  12.5,  13.5,  14.5,  15.5,  16.5,  17.5,
#           18.5,  19.5,  20.5,  21.5,  22.5,  23.6,  24.6,  25.6,  26.5,
#           27.5,  28.5,  29.5,  30.5,  31.5,  32.5,  33.5,  34.5,  35.5,
#           36.5,  37.5,  38.5,  39.5,  40.5,  41.5,  42.5,  43.5,  44.5,
#           45.5,  46.5,  47.5,  48.5,  49.5,  50.5,  51.5,  52.5,  53.5,
#           54.5,  55.5,  56.5,  57.5,  58.5,  59.5,  60.5,  61.5,  62.5,
#           63.5,  64.5,  65.5,  66.5,  67.6,  68.6,  69.5,  70.5,  71.5,
#           72.5,  73.5,  74.5,  75.5,  76.5,  77.5,  78.5,  79.5,  80.5,
#           81.5,  82.5,  83.5,  84.5,  85.5,  86.5,  87.5,  88.5,  89.5,
#           90.5,  91.5,  92.5,  93.5,  94.5,  95.5,  96.5,  97.5,  98.5,
#           99.5, 100.5, 101.5, 102.5, 103.5, 104.5, 105.5, 106.5, 107.5,
#          108.5, 109.5, 110.5, 111.5, 112.6, 113.6, 114.5, 115.5, 116.5,
#          117.5, 118.5, 119.5, 120.5, 121.5, 122.5, 123.5, 124.5, 125.5,
#          126.5, 127.5, 128.5, 129.5, 130.5, 131.5, 132.5, 133.5, 134.5,
#          135.5, 136.6, 137.5, 138.5, 139.6, 140.5, 141.5, 142.6, 143.5,
#          144.5, 145.5, 146.5, 147.5, 148.5, 149.5, 150.5, 151.5, 152.5,
#          153.5, 154.5, 155.5, 156.5, 157.5, 158.6, 159.5, 160.5, 161.5,
#          162.5, 163.5, 164.5, 165.5, 166.5, 167.5, 168.5, 169.5, 170.5,
#          171.5, 172.5, 173.5, 174.5, 175.5, 176.5, 177.5, 178.5, 179.5,
#          180.5, 181.5, 182.6, 183.6, 184.5, 185.5, 186.5, 187.5, 188.5,
#          189.5, 190.5, 191.5, 192.5, 193.5, 194.5, 195.5, 196.5, 197.5,
#          198.5, 199.5, 200.5, 201.5, 202.5, 203.5, 204.5, 205.5, 206.5,
#          207.5, 208.5, 209.5, 210.5, 211.5, 212.5, 213.5, 214.6, 215.5,
#          216.5, 217.5, 218.5, 218.5, 219.5, 220.5, 221.5, 222.5, 223.5,
#          224.5, 225.5, 226.6, 227.5, 228.5, 229.5, 230.5, 231.5, 232.5,
#          233.5, 234.5, 235.5, 236.5, 237.5, 238.6, 239.5, 240.5, 241.5,
#          242.6, 243.5, 244.5, 245.5, 246.5, 247.5, 248.5, 249.5, 250.5,
#          251.5, 252.6, 253.5, 254.5, 255.5, 256.5, 257.5, 258.5, 259.5,
#          260.5, 261.5, 262.5, 263.5, 264.5, 265.5, 266.5, 267.5, 268.5,
#          269.5, 270.5, 271.5, 272.5, 273.5, 274.5, 275.5, 276.5, 277.5,
#          278.5, 279.5, 280.5, 281.5, 282.5, 283.5, 284.5, 285.5, 286.5,
#          287.5, 288.5, 289.5, 290.5, 291.5, 292.6, 293.6, 294.5, 295.5,
#          296.5, 297.5, 298.5, 299.5, 300.5, 301.5, 302.5, 303.5, 304.5,
#          305.5, 306.5, 307.5, 308.5, 309.5, 310.5, 311.5, 312.5, 313.5,
#          314.5, 315.5, 316.5, 317.5, 318.5, 319.5, 320.5, 321.5, 322.5,
#          323.5, 324.5, 325.5, 326.5, 327.5, 328.5, 329.5, 330.5, 331.5,
#          332.5, 333.5, 334.5, 335.5, 336.5, 337.5, 338.6, 339.5, 340.5,
#          341.5, 342.5, 343.5, 344.5, 345.5, 346.5, 347.5, 348.5, 349.5,
#          350.5, 351.5, 352.5, 353.5, 354.5, 355.5, 356.5, 357.5, 358.5,
#          359.5]),
#   'el': np.float64(23.9996337890625),
#   'r': array([  500.,  1000.,  1500.,  2000.,  2500.,  3000.,  3500.,  4000.,
#           4500.,  5000.,  5500.,  6000.,  6500.,  7000.,  7500.,  8000.,
#           8500.,  9000.,  9500., 10000., 10500., 11000., 11500., 12000.,
#          12500., 13000., 13500., 14000., 14500., 15000., 15500., 16000.,
#          16500., 17000., 17500., 18000., 18500., 19000., 19500., 20000.,
#          20500., 21000., 21500., 22000., 22500., 23000., 23500., 24000.,
#          24500., 25000., 25500., 26000., 26500., 27000., 27500., 28000.,
#          28500., 29000., 29500., 30000., 30500., 31000., 31500., 32000.,
#          32500., 33000., 33500., 34000., 34500., 35000., 35500., 36000.,
#          36500., 37000., 37500., 38000., 38500., 39000., 39500., 40000.,
#          40500., 41000., 41500., 42000., 42500., 43000., 43500., 44000.,
#          44500., 45000., 45500., 46000., 46500., 47000., 47500., 48000.,
#          48500., 49000., 49500., 50000., 50500., 51000., 51500., 52000.,
#          52500., 53000., 53500., 54000., 54500., 55000., 55500., 56000.,
#          56500., 57000., 57500., 58000., 58500., 59000., 59500., 60000.]),
#   'Time': '2024-08-14T00:02:39.507Z',
#   'max_range': np.float64(60000.0)},
#  'SCAN13': {'PRF': np.uint32(1180),
#   'adc_hh_temperature': np.float64(58.0),
#   'adc_hh_temperature__unit': 'degC',
#   'adc_hl_temperature': np.float64(56.0),
#   'adc_hl_temperature__unit': 'degC',
#   'adc_vh_temperature': np.float64(55.0),
#   'adc_vh_temperature__unit': 'degC',
#   'adc_vl_temperature': np.float64(58.0),
#   'adc_vl_temperature__unit': 'degC',
#   'angle_step': np.float64(1.0),
#   'angle_sync': np.uint8(1),
#   'ant_gain_h': np.float64(45.7),
#   'ant_gain_h__unit': 'dB',
#   'ant_gain_ldrh': np.float64(45.7),
#   'ant_gain_ldrh__unit': 'dB',
#   'ant_gain_ldrv': np.float64(43.0),
#   'ant_gain_ldrv__unit': 'dB',
#   'ant_gain_v': np.float64(45.8),
#   'ant_gain_v__unit': 'dB',
#   'azi_start': np.float64(0.0),
#   'azi_stop': np.float64(0.0),
#   'bin_count': np.uint32(120),
#   'clutter_filter_number': np.uint32(4),
#   'cpu_temp_0': np.float64(34.0),
#   'cpu_temp_0__unit': 'degC',
#   'cpu_temp_1': np.float64(0.0),
#   'cpu_temp_1__unit': 'degC',
#   'cpu_temp_2': np.float64(0.0),
#   'cpu_temp_2__unit': 'degC',
#   'cpu_temp_3': np.float64(0.0),
#   'cpu_temp_3__unit': 'degC',
#   'dbm0_h': np.float64(-106.231),
#   'dbm0_h__unit': 'dB',
#   'dbm0_v': np.float64(-105.436),
#   'dbm0_v__unit': 'dB',
#   'dbz0_h': np.float64(-35.1336),
#   'dbz0_h__unit': 'dBZ',
#   'dbz0_v': np.float64(-34.679),
#   'dbz0_v__unit': 'dBZ',
#   'elevation': np.float64(29.9981689453125),
#   'gas_attenuation': np.float64(0.016),
#   'gas_attenuation__unit': 'dB/km',
#   'ldr_offset': np.float64(0.0),
#   'ldr_offset__unit': 'dB',
#   'malfunc': np.uint8(0),
#   'mb_temp_0': np.float64(31.0),
#   'mb_temp_0__unit': 'degC',
#   'mb_temp_1': np.float64(0.0),
#   'mb_temp_1__unit': 'degC',
#   'mb_temp_2': np.float64(0.0),
#   'mb_temp_2__unit': 'degC',
#   'mb_temp_3': np.float64(0.0),
#   'mb_temp_3__unit': 'degC',
#   'noise_power_h': np.float64(2.10011),
#   'noise_power_h__unit': 'dB',
#   'noise_power_v': np.float64(2.96022),
#   'noise_power_v__unit': 'dB',
#   'noise_threshold': np.float64(0.0),
#   'noise_threshold__unit': 'dB',
#   'nyquist_velocity': np.float64(15.7471),
#   'nyquist_velocity__unit': 'm/s',
#   'phidp_offset': np.float64(0.0),
#   'phidp_offset__unit': 'deg',
#   'pulse_width_number': '4',
#   'pulse_width_us': np.float64(0.8050000071525574),
#   'pulse_width_us_0': np.float64(0.4),
#   'pulse_width_us_0__unit': 'us',
#   'pulse_width_us_1': np.float64(0.805),
#   'pulse_width_us_1__unit': 'us',
#   'pulse_width_us_2': np.float64(1.0),
#   'pulse_width_us_2__unit': 'us',
#   'pulse_width_us_3': np.float64(2.0),
#   'pulse_width_us_3__unit': 'us',
#   'radar_wave_length': np.float64(0.053380001336336136),
#   'range': np.float64(60000.0),
#   'range_samples': np.uint32(4),
#   'range_start': np.float64(0.0),
#   'range_step': np.float64(125.0),
#   'raster': 'off',
#   'ray_count': np.uint32(360),
#   'rx_loss_h': np.float64(3.59),
#   'rx_loss_h__unit': 'dB',
#   'rx_loss_ldrh': np.float64(3.59),
#   'rx_loss_ldrh__unit': 'dB',
#   'rx_loss_ldrv': np.float64(4.1),
#   'rx_loss_ldrv__unit': 'dB',
#   'rx_loss_v': np.float64(4.11),
#   'rx_loss_v__unit': 'dB',
#   'scan_speed': np.float64(30.0),
#   'swap_phidp': 'off',
#   'time_samples': np.uint32(16),
#   'tsg_loss_h': np.float64(0.0),
#   'tsg_loss_h__unit': 'dB',
#   'tsg_loss_ldrh': np.float64(0.0),
#   'tsg_loss_ldrh__unit': 'dB',
#   'tsg_loss_ldrv': np.float64(11.4),
#   'tsg_loss_ldrv__unit': 'dB',
#   'tsg_loss_v': np.float64(0.0),
#   'tsg_loss_v__unit': 'dB',
#   'tx_loss_h': np.float64(4.93),
#   'tx_loss_h__unit': 'dB',
#   'tx_loss_ldrh': np.float64(1.92),
#   'tx_loss_ldrh__unit': 'dB',
#   'tx_loss_ldrv': np.float64(1.6),
#   'tx_loss_ldrv__unit': 'dB',
#   'tx_loss_v': np.float64(4.79),
#   'tx_loss_v__unit': 'dB',
#   'txd_peak_power': np.float64(217.771),
#   'txd_peak_power__unit': 'kW',
#   'unambiguous_velocity': np.float64(47.2413),
#   'unambiguous_velocity__unit': 'm/s',
#   'unfolding': np.uint32(2),
#   'unfolding_str': '3/4',
#   'zdr1_offset': np.float64(0.0),
#   'zdr1_offset__unit': 'dB',
#   'zdr_offset': np.float64(-0.42),
#   'zdr_offset__unit': 'dB',
#   'bin_range': np.float64(500.0),
#   'zero_index': np.int64(92),
#   'az': array([  0.5,   1.5,   2.5,   3.5,   4.5,   5.5,   6.5,   7.5,   8.5,
# ...
#   'cpu_temp_3__unit': 'degC',
#   'dbm0_h': np.float64(-106.231),
#   'dbm0_h__unit': 'dB',
#   'dbm0_v': np.float64(-105.436),
#   'dbm0_v__unit': 'dB',
#   'dbz0_h': np.float64(-35.1336),
#   'dbz0_h__unit': 'dBZ',
#   'dbz0_v': np.float64(-34.679),
#   'dbz0_v__unit': 'dBZ',
#   'elevation': np.float64(10.997314453125),
#   'gas_attenuation': np.float64(0.016),
#   'gas_attenuation__unit': 'dB/km',
#   'ldr_offset': np.float64(0.0),
#   'ldr_offset__unit': 'dB',
#   'malfunc': np.uint8(0),
#   'mb_temp_0': np.float64(31.0),
#   'mb_temp_0__unit': 'degC',
#   'mb_temp_1': np.float64(0.0),
#   'mb_temp_1__unit': 'degC',
#   'mb_temp_2': np.float64(0.0),
#   'mb_temp_2__unit': 'degC',
#   'mb_temp_3': np.float64(0.0),
#   'mb_temp_3__unit': 'degC',
#   'noise_power_h': np.float64(2.10011),
#   'noise_power_h__unit': 'dB',
#   'noise_power_v': np.float64(2.96022),
#   'noise_power_v__unit': 'dB',
#   'noise_threshold': np.float64(0.0),
#   'noise_threshold__unit': 'dB',
#   'nyquist_velocity': np.float64(15.7471),
#   'nyquist_velocity__unit': 'm/s',
#   'phidp_offset': np.float64(0.0),
#   'phidp_offset__unit': 'deg',
#   'pulse_width_number': '4',
#   'pulse_width_us': np.float64(0.8050000071525574),
#   'pulse_width_us_0': np.float64(0.4),
#   'pulse_width_us_0__unit': 'us',
#   'pulse_width_us_1': np.float64(0.805),
#   'pulse_width_us_1__unit': 'us',
#   'pulse_width_us_2': np.float64(1.0),
#   'pulse_width_us_2__unit': 'us',
#   'pulse_width_us_3': np.float64(2.0),
#   'pulse_width_us_3__unit': 'us',
#   'radar_wave_length': np.float64(0.053380001336336136),
#   'range': np.float64(80000.0),
#   'range_samples': np.uint32(4),
#   'range_start': np.float64(0.0),
#   'range_step': np.float64(125.0),
#   'raster': 'off',
#   'ray_count': np.uint32(360),
#   'rx_loss_h': np.float64(3.59),
#   'rx_loss_h__unit': 'dB',
#   'rx_loss_ldrh': np.float64(3.59),
#   'rx_loss_ldrh__unit': 'dB',
#   'rx_loss_ldrv': np.float64(4.1),
#   'rx_loss_ldrv__unit': 'dB',
#   'rx_loss_v': np.float64(4.11),
#   'rx_loss_v__unit': 'dB',
#   'scan_speed': np.float64(30.0),
#   'swap_phidp': 'off',
#   'time_samples': np.uint32(16),
#   'tsg_loss_h': np.float64(0.0),
#   'tsg_loss_h__unit': 'dB',
#   'tsg_loss_ldrh': np.float64(0.0),
#   'tsg_loss_ldrh__unit': 'dB',
#   'tsg_loss_ldrv': np.float64(11.4),
#   'tsg_loss_ldrv__unit': 'dB',
#   'tsg_loss_v': np.float64(0.0),
#   'tsg_loss_v__unit': 'dB',
#   'tx_loss_h': np.float64(4.93),
#   'tx_loss_h__unit': 'dB',
#   'tx_loss_ldrh': np.float64(1.92),
#   'tx_loss_ldrh__unit': 'dB',
#   'tx_loss_ldrv': np.float64(1.6),
#   'tx_loss_ldrv__unit': 'dB',
#   'tx_loss_v': np.float64(4.79),
#   'tx_loss_v__unit': 'dB',
#   'txd_peak_power': np.float64(217.771),
#   'txd_peak_power__unit': 'kW',
#   'unambiguous_velocity': np.float64(47.2413),
#   'unambiguous_velocity__unit': 'm/s',
#   'unfolding': np.uint32(2),
#   'unfolding_str': '3/4',
#   'zdr1_offset': np.float64(0.0),
#   'zdr1_offset__unit': 'dB',
#   'zdr_offset': np.float64(-0.42),
#   'zdr_offset__unit': 'dB',
#   'bin_range': np.float64(500.0),
#   'zero_index': np.int64(285),
#   'az': array([  0.5,   1.5,   2.5,   3.5,   4.5,   5.5,   6.5,   7.5,   8.5,
#            9.5,  10.5,  11.5,  12.5,  13.5,  14.5,  15.5,  16.5,  17.5,
#           18.5,  19.5,  20.5,  21.5,  22.5,  23.5,  24.5,  25.5,  26.5,
#           27.5,  28.5,  29.5,  30.5,  31.5,  32.5,  33.5,  34.5,  35.5,
#           36.5,  37.5,  38.5,  39.5,  40.5,  41.5,  42.5,  43.5,  44.6,
#           45.5,  46.5,  47.5,  48.5,  49.5,  50.5,  51.5,  52.5,  53.5,
#           54.5,  55.5,  56.5,  57.5,  58.5,  59.5,  60.5,  61.5,  62.5,
#           63.5,  64.5,  65.5,  66.5,  67.5,  68.5,  69.5,  70.5,  71.5,
#           72.5,  73.5,  74.5,  75.5,  76.5,  77.5,  78.5,  79.5,  80.5,
#           81.5,  82.6,  83.5,  84.5,  85.5,  86.5,  87.5,  88.6,  89.5,
#           90.5,  91.5,  92.5,  93.5,  94.5,  95.5,  96.5,  97.5,  98.5,
#           99.5, 100.5, 101.5, 102.5, 103.5, 104.5, 105.5, 106.5, 107.5,
#          108.5, 109.5, 110.5, 111.5, 112.5, 113.5, 114.5, 115.5, 116.5,
#          117.5, 118.5, 119.5, 120.5, 121.5, 122.5, 123.5, 124.5, 125.5,
#          126.5, 127.5, 128.5, 129.5, 130.5, 131.5, 132.5, 133.5, 134.5,
#          135.5, 136.5, 137.5, 138.5, 139.5, 140.5, 141.5, 142.5, 143.5,
#          144.5, 145.5, 146.5, 147.5, 148.5, 149.5, 150.5, 151.5, 152.5,
#          153.5, 154.5, 155.5, 156.5, 157.5, 158.5, 159.5, 160.5, 161.5,
#          162.5, 163.5, 164.5, 165.5, 166.5, 167.5, 168.5, 169.5, 170.5,
#          171.5, 172.5, 173.5, 174.5, 175.5, 176.5, 177.5, 178.5, 179.6,
#          180.5, 181.5, 182.5, 183.5, 184.5, 185.5, 186.5, 187.5, 188.5,
#          189.5, 190.5, 191.5, 192.5, 193.5, 194.5, 195.5, 196.5, 197.5,
#          198.5, 199.5, 200.5, 201.5, 202.5, 203.5, 204.5, 205.5, 206.5,
#          207.5, 208.5, 209.5, 210.5, 211.5, 212.5, 213.5, 214.5, 215.5,
#          216.6, 217.5, 218.5, 219.5, 220.5, 221.5, 222.5, 223.5, 224.5,
#          225.5, 226.5, 227.6, 228.5, 229.5, 230.5, 231.5, 232.5, 233.5,
#          234.5, 235.5, 236.5, 237.5, 238.5, 239.5, 240.5, 241.5, 242.5,
#          243.5, 244.5, 245.5, 246.5, 247.5, 248.5, 249.5, 250.5, 251.5,
#          252.5, 253.5, 254.5, 255.5, 256.5, 257.5, 258.5, 259.5, 260.5,
#          261.5, 262.5, 263.5, 264.5, 265.6, 266.6, 267.5, 268.5, 269.5,
#          270.5, 271.5, 272.5, 273.5, 274.5, 275.5, 276.5, 277.5, 278.5,
#          279.5, 280.5, 281.5, 282.5, 283.5, 284.5, 285.5, 286.5, 287.5,
#          288.5, 289.5, 290.5, 291.5, 292.5, 293.5, 294.5, 295.5, 296.5,
#          297.5, 298.5, 299.5, 300.5, 301.5, 302.5, 303.5, 304.5, 305.5,
#          306.6, 307.5, 308.5, 309.5, 310.5, 311.5, 312.5, 313.6, 314.6,
#          315.5, 316.5, 317.5, 318.5, 319.5, 320.5, 321.5, 322.5, 323.5,
#          324.5, 325.5, 326.5, 327.5, 328.5, 329.5, 330.5, 331.5, 332.5,
#          333.5, 334.5, 335.5, 336.5, 337.5, 338.5, 339.5, 340.5, 341.5,
#          342.5, 343.5, 344.5, 345.5, 346.5, 347.5, 348.5, 349.5, 350.5,
#          351.5, 352.5, 353.5, 354.5, 355.5, 356.6, 357.5, 358.5, 359.5]),
#   'el': np.float64(10.997314453125),
#   'r': array([  500.,  1000.,  1500.,  2000.,  2500.,  3000.,  3500.,  4000.,
#           4500.,  5000.,  5500.,  6000.,  6500.,  7000.,  7500.,  8000.,
#           8500.,  9000.,  9500., 10000., 10500., 11000., 11500., 12000.,
#          12500., 13000., 13500., 14000., 14500., 15000., 15500., 16000.,
#          16500., 17000., 17500., 18000., 18500., 19000., 19500., 20000.,
#          20500., 21000., 21500., 22000., 22500., 23000., 23500., 24000.,
#          24500., 25000., 25500., 26000., 26500., 27000., 27500., 28000.,
#          28500., 29000., 29500., 30000., 30500., 31000., 31500., 32000.,
#          32500., 33000., 33500., 34000., 34500., 35000., 35500., 36000.,
#          36500., 37000., 37500., 38000., 38500., 39000., 39500., 40000.,
#          40500., 41000., 41500., 42000., 42500., 43000., 43500., 44000.,
#          44500., 45000., 45500., 46000., 46500., 47000., 47500., 48000.,
#          48500., 49000., 49500., 50000., 50500., 51000., 51500., 52000.,
#          52500., 53000., 53500., 54000., 54500., 55000., 55500., 56000.,
#          56500., 57000., 57500., 58000., 58500., 59000., 59500., 60000.,
#          60500., 61000., 61500., 62000., 62500., 63000., 63500., 64000.,
#          64500., 65000., 65500., 66000., 66500., 67000., 67500., 68000.,
#          68500., 69000., 69500., 70000., 70500., 71000., 71500., 72000.,
#          72500., 73000., 73500., 74000., 74500., 75000., 75500., 76000.,
#          76500., 77000., 77500., 78000., 78500., 79000., 79500., 80000.]),
#   'Time': '2024-08-14T00:01:46.736Z',
#   'max_range': np.float64(80000.0)},
#  'SCAN9': {'PRF': np.uint32(1180),
#   'adc_hh_temperature': np.float64(58.0),
#   'adc_hh_temperature__unit': 'degC',
#   'adc_hl_temperature': np.float64(56.0),
#   'adc_hl_temperature__unit': 'degC',
#   'adc_vh_temperature': np.float64(56.0),
#   'adc_vh_temperature__unit': 'degC',
#   'adc_vl_temperature': np.float64(58.0),
#   'adc_vl_temperature__unit': 'degC',
#   'angle_step': np.float64(1.0),
#   'angle_sync': np.uint8(1),
#   'ant_gain_h': np.float64(45.7),
#   'ant_gain_h__unit': 'dB',
#   'ant_gain_ldrh': np.float64(45.7),
#   'ant_gain_ldrh__unit': 'dB',
#   'ant_gain_ldrv': np.float64(43.0),
#   'ant_gain_ldrv__unit': 'dB',
#   'ant_gain_v': np.float64(45.8),
#   'ant_gain_v__unit': 'dB',
#   'azi_start': np.float64(0.0),
#   'azi_stop': np.float64(0.0),
#   'bin_count': np.uint32(160),
#   'clutter_filter_number': np.uint32(4),
#   'cpu_temp_0': np.float64(34.0),
#   'cpu_temp_0__unit': 'degC',
#   'cpu_temp_1': np.float64(0.0),
#   'cpu_temp_1__unit': 'degC',
#   'cpu_temp_2': np.float64(0.0),
#   'cpu_temp_2__unit': 'degC',
#   'cpu_temp_3': np.float64(0.0),
#   'cpu_temp_3__unit': 'degC',
#   'dbm0_h': np.float64(-106.231),
#   'dbm0_h__unit': 'dB',
#   'dbm0_v': np.float64(-105.436),
#   'dbm0_v__unit': 'dB',
#   'dbz0_h': np.float64(-35.1336),
#   'dbz0_h__unit': 'dBZ',
#   'dbz0_v': np.float64(-34.679),
#   'dbz0_v__unit': 'dBZ',
#   'elevation': np.float64(13.0023193359375),
#   'gas_attenuation': np.float64(0.016),
#   'gas_attenuation__unit': 'dB/km',
#   'ldr_offset': np.float64(0.0),
#   'ldr_offset__unit': 'dB',
#   'malfunc': np.uint8(0),
#   'mb_temp_0': np.float64(31.0),
#   'mb_temp_0__unit': 'degC',
#   'mb_temp_1': np.float64(0.0),
#   'mb_temp_1__unit': 'degC',
#   'mb_temp_2': np.float64(0.0),
#   'mb_temp_2__unit': 'degC',
#   'mb_temp_3': np.float64(0.0),
#   'mb_temp_3__unit': 'degC',
#   'noise_power_h': np.float64(2.10011),
#   'noise_power_h__unit': 'dB',
#   'noise_power_v': np.float64(2.96022),
#   'noise_power_v__unit': 'dB',
#   'noise_threshold': np.float64(0.0),
#   'noise_threshold__unit': 'dB',
#   'nyquist_velocity': np.float64(15.7471),
#   'nyquist_velocity__unit': 'm/s',
#   'phidp_offset': np.float64(0.0),
#   'phidp_offset__unit': 'deg',
#   'pulse_width_number': '4',
#   'pulse_width_us': np.float64(0.8050000071525574),
#   'pulse_width_us_0': np.float64(0.4),
#   'pulse_width_us_0__unit': 'us',
#   'pulse_width_us_1': np.float64(0.805),
#   'pulse_width_us_1__unit': 'us',
#   'pulse_width_us_2': np.float64(1.0),
#   'pulse_width_us_2__unit': 'us',
#   'pulse_width_us_3': np.float64(2.0),
#   'pulse_width_us_3__unit': 'us',
#   'radar_wave_length': np.float64(0.053380001336336136),
#   'range': np.float64(80000.0),
#   'range_samples': np.uint32(4),
#   'range_start': np.float64(0.0),
#   'range_step': np.float64(125.0),
#   'raster': 'off',
#   'ray_count': np.uint32(361),
#   'rx_loss_h': np.float64(3.59),
#   'rx_loss_h__unit': 'dB',
#   'rx_loss_ldrh': np.float64(3.59),
#   'rx_loss_ldrh__unit': 'dB',
#   'rx_loss_ldrv': np.float64(4.1),
#   'rx_loss_ldrv__unit': 'dB',
#   'rx_loss_v': np.float64(4.11),
#   'rx_loss_v__unit': 'dB',
#   'scan_speed': np.float64(30.0),
#   'swap_phidp': 'off',
#   'time_samples': np.uint32(16),
#   'tsg_loss_h': np.float64(0.0),
#   'tsg_loss_h__unit': 'dB',
#   'tsg_loss_ldrh': np.float64(0.0),
#   'tsg_loss_ldrh__unit': 'dB',
#   'tsg_loss_ldrv': np.float64(11.4),
#   'tsg_loss_ldrv__unit': 'dB',
#   'tsg_loss_v': np.float64(0.0),
#   'tsg_loss_v__unit': 'dB',
#   'tx_loss_h': np.float64(4.93),
#   'tx_loss_h__unit': 'dB',
#   'tx_loss_ldrh': np.float64(1.92),
#   'tx_loss_ldrh__unit': 'dB',
#   'tx_loss_ldrv': np.float64(1.6),
#   'tx_loss_ldrv__unit': 'dB',
#   'tx_loss_v': np.float64(4.79),
#   'tx_loss_v__unit': 'dB',
#   'txd_peak_power': np.float64(217.771),
#   'txd_peak_power__unit': 'kW',
#   'unambiguous_velocity': np.float64(47.2413),
#   'unambiguous_velocity__unit': 'm/s',
#   'unfolding': np.uint32(2),
#   'unfolding_str': '3/4',
#   'zdr1_offset': np.float64(0.0),
#   'zdr1_offset__unit': 'dB',
#   'zdr_offset': np.float64(-0.42),
#   'zdr_offset__unit': 'dB',
#   'bin_range': np.float64(500.0),
#   'zero_index': np.int64(257),
#   'az': array([  0.5,   1.6,   2.6,   3.5,   4.5,   5.5,   6.5,   7.5,   8.5,
#            9.5,  10.6,  11.5,  12.5,  13.5,  14.5,  15.5,  16.5,  17.5,
#           18.5,  19.5,  20.5,  21.5,  22.5,  23.5,  24.5,  25.5,  26.5,
#           27.5,  28.5,  29.5,  30.5,  31.6,  32.5,  33.5,  34.5,  35.5,
#           36.5,  37.6,  38.5,  39.5,  40.5,  41.5,  42.5,  43.5,  44.5,
#           45.5,  46.5,  47.5,  48.5,  49.5,  50.5,  51.5,  52.5,  53.5,
#           54.5,  55.5,  56.5,  57.5,  58.5,  59.5,  60.5,  61.5,  62.5,
#           63.6,  64.5,  65.5,  66.5,  67.5,  68.5,  69.6,  70.5,  71.5,
#           72.5,  73.5,  74.5,  75.5,  76.5,  77.5,  78.5,  79.5,  80.5,
#           81.5,  82.5,  83.5,  84.5,  85.5,  86.5,  87.5,  88.5,  89.5,
#           90.5,  91.5,  92.5,  93.5,  94.5,  95.5,  96.5,  97.6,  98.5,
#           99.5, 100.5, 101.6, 102.5, 103.5, 103.5, 104.5, 105.5, 106.5,
#          107.5, 108.5, 109.5, 110.5, 111.5, 112.5, 113.5, 114.5, 115.5,
#          116.5, 117.5, 118.5, 119.5, 120.5, 121.5, 122.5, 123.5, 124.5,
#          125.5, 126.5, 127.5, 128.5, 129.5, 130.5, 131.5, 132.5, 133.5,
#          134.5, 135.5, 136.5, 137.5, 138.5, 139.5, 140.5, 141.5, 142.5,
#          143.6, 144.5, 145.5, 146.5, 147.5, 148.5, 149.5, 150.5, 151.5,
#          152.5, 153.5, 154.5, 155.5, 156.5, 157.5, 158.5, 159.5, 160.5,
#          161.5, 162.5, 163.5, 164.5, 165.5, 166.5, 167.5, 168.5, 169.5,
#          170.5, 171.6, 172.6, 173.5, 174.6, 175.5, 176.5, 177.5, 178.6,
#          179.6, 180.5, 181.5, 182.5, 183.6, 184.5, 185.5, 186.5, 187.5,
#          188.5, 189.5, 190.6, 191.5, 192.5, 193.5, 194.5, 195.5, 196.5,
#          197.5, 198.5, 199.5, 200.5, 201.5, 202.5, 203.5, 204.5, 205.5,
#          206.5, 207.5, 208.5, 209.5, 210.5, 211.5, 212.5, 213.5, 214.5,
#          215.5, 216.5, 217.6, 218.5, 219.5, 220.5, 221.5, 222.5, 223.5,
#          224.5, 225.5, 226.5, 227.6, 228.5, 229.5, 230.5, 231.5, 232.5,
#          233.5, 234.5, 235.5, 236.5, 237.5, 238.5, 239.5, 240.5, 241.5,
#          242.5, 243.5, 244.5, 245.5, 246.5, 247.5, 248.5, 249.5, 250.5,
#          251.6, 252.5, 253.5, 254.5, 255.5, 256.5, 257.5, 258.5, 259.5,
#          260.5, 261.6, 262.5, 263.5, 264.5, 265.5, 266.5, 267.5, 268.5,
#          269.6, 270.5, 271.5, 272.5, 273.5, 274.5, 275.5, 276.5, 277.5,
#          278.5, 279.5, 280.5, 281.5, 282.5, 283.5, 284.5, 285.5, 286.5,
#          287.6, 288.5, 289.5, 290.5, 291.5, 292.5, 293.5, 294.5, 295.5,
#          296.5, 297.5, 298.5, 299.5, 300.5, 301.5, 302.5, 303.5, 304.5,
#          305.5, 306.6, 307.5, 308.5, 309.5, 310.5, 311.5, 312.5, 313.5,
#          314.5, 315.5, 316.5, 317.5, 318.5, 319.5, 320.5, 321.5, 322.5,
#          323.5, 324.5, 325.5, 326.5, 327.5, 328.5, 329.5, 330.5, 331.5,
#          332.5, 333.5, 334.5, 335.5, 336.5, 337.5, 338.5, 339.5, 340.5,
#          341.5, 342.5, 343.5, 344.5, 345.5, 346.5, 347.5, 348.5, 349.5,
#          350.5, 351.6, 352.6, 353.5, 354.5, 355.5, 356.5, 357.5, 358.5,
#          359.5]),
#   'el': np.float64(13.0023193359375),
#   'r': array([  500.,  1000.,  1500.,  2000.,  2500.,  3000.,  3500.,  4000.,
#           4500.,  5000.,  5500.,  6000.,  6500.,  7000.,  7500.,  8000.,
#           8500.,  9000.,  9500., 10000., 10500., 11000., 11500., 12000.,
#          12500., 13000., 13500., 14000., 14500., 15000., 15500., 16000.,
#          16500., 17000., 17500., 18000., 18500., 19000., 19500., 20000.,
#          20500., 21000., 21500., 22000., 22500., 23000., 23500., 24000.,
#          24500., 25000., 25500., 26000., 26500., 27000., 27500., 28000.,
#          28500., 29000., 29500., 30000., 30500., 31000., 31500., 32000.,
#          32500., 33000., 33500., 34000., 34500., 35000., 35500., 36000.,
#          36500., 37000., 37500., 38000., 38500., 39000., 39500., 40000.,
#          40500., 41000., 41500., 42000., 42500., 43000., 43500., 44000.,
#          44500., 45000., 45500., 46000., 46500., 47000., 47500., 48000.,
#          48500., 49000., 49500., 50000., 50500., 51000., 51500., 52000.,
#          52500., 53000., 53500., 54000., 54500., 55000., 55500., 56000.,
#          56500., 57000., 57500., 58000., 58500., 59000., 59500., 60000.,
#          60500., 61000., 61500., 62000., 62500., 63000., 63500., 64000.,
#          64500., 65000., 65500., 66000., 66500., 67000., 67500., 68000.,
#          68500., 69000., 69500., 70000., 70500., 71000., 71500., 72000.,
#          72500., 73000., 73500., 74000., 74500., 75000., 75500., 76000.,
#          76500., 77000., 77500., 78000., 78500., 79000., 79500., 80000.]),
#   'Time': '2024-08-14T00:01:59.670Z',
#   'max_range': np.float64(80000.0)},
#  'VOL': {'Latitude': np.float64(49.094167),
#   'Longitude': np.float64(8.436667),
#   'Height': np.float64(148.0)}}

# %%
print(data.keys())
print(data["SCAN0"].keys())
print(data["SCAN0"]["PHIDP"].keys())
print(data["SCAN0"]["PHIDP"]["data"])
print(data["SCAN0"]["PHIDP"]["data"].shape)
print(data["SCAN0"]["PHIDP"]["data"].dtype)
# Out:
# dict_keys(['SCAN0', 'SCAN1', 'SCAN10', 'SCAN11', 'SCAN12', 'SCAN13', 'SCAN2', 'SCAN3', 'SCAN4', 'SCAN5', 'SCAN6', 'SCAN7', 'SCAN8', 'SCAN9'])
# dict_keys(['ZH', 'ZV', 'SQIH', 'CCORH', 'SNRH', 'UZH', 'UZV', 'ZDR', 'VH', 'WH', 'PHIDP', 'KDP', 'RHOHV'])
# dict_keys(['data', 'dyn_range_max', 'dyn_range_min'])
# [[ 140.31497   157.32285   174.33072  ...  111.968506  111.968506
#    106.299225]
#  [ 177.16534   144.56693   143.1496   ...  120.47244   116.22046
#    117.63779 ]
#  [ 181.41733   167.24408   165.82678  ...  128.97638   114.80316
#    111.968506]
#  ...
#  [ 181.41733   180.       -131.81102  ...  106.299225  114.80316
#    110.55118 ]
#  [ 170.07874   170.07874  -148.8189   ...  100.62991   107.71652
#    102.04724 ]
#  [ 136.06299   165.82678  -168.66142  ...  102.04724   110.55118
#    106.299225]]
# (361, 240)
# float32

# %%
shape = (data["SCAN0"]["PHIDP"]["data"].shape)
shape
# Out:
# (361, 240)

# %%
data["SCAN0"]["PHIDP"]["data"].dtype
# Out:
# dtype('float32')
